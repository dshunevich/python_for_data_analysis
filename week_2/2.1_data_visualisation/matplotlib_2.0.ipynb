# %% [markdown]
# documentation matplotlib.axes.Axes  - https://matplotlib.org/api/axes_api.html
# documentation matplotlib.figure.Figure - https://matplotlib.org/api/_as_gen/matplotlib.figure.Figure.html

# %%
from numpy.random import exponential
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axes = plt.subplots()
axes.plot(exponential(5, 20))
axes.set_title('Chart')
# Out:
# Text(0.5, 1.0, 'Chart')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))
for row, row_axes in enumerate(axes):
  for column, ax in enumerate(row_axes):
    ax.plot(exponential(column, 20))
    ax.set_title(f'Canvas column {column+1} row {row+1}')
fig.tight_layout()

# %%
fig.savefig('all_results.png')
